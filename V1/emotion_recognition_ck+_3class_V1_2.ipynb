# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import pandas as pd
import numpy as np
import tensorflow as tf
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
df = pd.read_csv('/content/drive/MyDrive/face_emotion/Dataset/ckextended.csv')
df.head()
# Out:
#    emotion                                             pixels     Usage
# 0        6  36 39 35 25 19 11 8 7 3 13 15 9 21 57 75 90 10...  Training
# 1        6  88 74 19 4 5 5 3 12 8 21 15 21 15 18 24 29 32 ...  Training
# 2        6  9 2 4 7 1 1 1 0 7 29 49 76 115 141 156 169 177...  Training
# 3        6  104 106 108 104 95 50 60 61 58 83 126 133 139 ...  Training
# 4        6  68 72 67 67 6 2 1 1 1 1 1 14 24 24 38 65 79 94...  Training

# %%
df['emotion'].value_counts()
# Out:
# 6    593
# 5     83
# 3     69
# 1     59
# 0     45
# 4     28
# 2     25
# 7     18
# Name: emotion, dtype: int64

# %%
# mapping into positive, negative, neutral
# Create a dictionary to define the class mapping
class_mapping = {
    3: 0,  # happiness (Positive)
    5: 0,  # surprise (Positive)
    6: 1,  # Neutral
    0: 2,  # anger (Negative)
    1: 2,  # disgust (Negative)
    2: 2,  # fear (Negative)
    4: 2,  # sadness (Negative)
    7: 2,  # contemp (Negative)
}

# Map the 'emotion' column
df['emotion'] = df['emotion'].map(class_mapping)

# %%
df.head()
# Out:
#    emotion                                             pixels     Usage
# 0        1  36 39 35 25 19 11 8 7 3 13 15 9 21 57 75 90 10...  Training
# 1        1  88 74 19 4 5 5 3 12 8 21 15 21 15 18 24 29 32 ...  Training
# 2        1  9 2 4 7 1 1 1 0 7 29 49 76 115 141 156 169 177...  Training
# 3        1  104 106 108 104 95 50 60 61 58 83 126 133 139 ...  Training
# 4        1  68 72 67 67 6 2 1 1 1 1 1 14 24 24 38 65 79 94...  Training

# %%
df['emotion'].value_counts()
# Out:
# 1    593
# 2    175
# 0    152
# Name: emotion, dtype: int64

# %%
df.to_csv('ckextended_3class.csv', index=False)

# %%
#label_to_text = {0:'anger', 1:'disgust', 2:'fear', 3:'happiness', 4: 'sadness', 5: 'surprise', 6: 'neutral', 7 : 'contempt'}  #original
label_to_text = {0:'positive', 1:'neutral', 2:'negative'}  #edit

# %%
img_array = df.pixels.apply(lambda x: np.array(x.split(" ")).reshape(48,48,1).astype('float32'))
img_array = np.stack(img_array, axis=0)
labels = df.emotion.values

# %%
img_array.shape
# Out:
# (920, 48, 48, 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(img_array, labels, test_size= .1, random_state=42, stratify=labels)

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((828, 48, 48, 1), (828,), (92, 48, 48, 1), (92,))

# %%
X_train = X_train/255
X_test = X_test/255

# %%
num_classes = 3

basemodel = tf.keras.models.Sequential([
                                        tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(48, 48, 1)),
                                        tf.keras.layers.MaxPool2D(2, 2),
                                        tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
                                        tf.keras.layers.MaxPool2D(2, 2),
                                        tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
                                        tf.keras.layers.Flatten(),
                                        tf.keras.layers.Dense(32, activation='relu'),
                                        #tf.keras.layers.Dropout(0.5),
                                        tf.keras.layers.Dense(num_classes, activation='softmax')
])

# %%
basemodel.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 46, 46, 32)        320
#
#  max_pooling2d (MaxPooling2  (None, 23, 23, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 21, 21, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 10, 10, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 8, 8, 128)         73856
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 32)                262176
#
#  dense_1 (Dense)             (None, 3)                 99
#
# =================================================================
# Total params: 354947 (1.35 MB)
# Trainable params: 354947 (1.35 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
initial_learning_rate = 0.0001  # You can adjust this value
optimizer = tf.keras.optimizers.RMSprop(learning_rate=initial_learning_rate)
#optimizer=tf.keras.optimizers.Adam(learning_rate=initial_learning_rate)
basemodel.compile(optimizer=optimizer,
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy'])

# %%
def lr_schedule(epoch):
    if epoch < 20:
        return initial_learning_rate
    else:
        return initial_learning_rate * 0.1

# %%
file_name = 'best_model.h5'
checkpoint_path= os.path.join('checkpoint',file_name)


call_back = [
    tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                        monitor='val_accuracy',
                                        verbose=1,
                                        save_freq='epoch',
                                        save_best_only=True,
                                        save_weights_only=False,
                                        mode='max'),
    tf.keras.callbacks.EarlyStopping(
        monitor='val_loss',
        patience=10,
        restore_best_weights=True
    ),
    tf.keras.callbacks.LearningRateScheduler(lr_schedule)
]

# %%
history = basemodel.fit(X_train, y_train,
                        validation_split=.1,
                        epochs=100,
                        batch_size=32,
                        callbacks=call_back)
# Out:
# Epoch 1/100
# 23/24 [===========================>..] - ETA: 0s - loss: 0.9395 - accuracy: 0.6291
# Epoch 1: val_accuracy improved from -inf to 0.69880, saving model to checkpoint/best_model.h5
# 24/24 [==============================] - 3s 105ms/step - loss: 0.9431 - accuracy: 0.6268 - val_loss: 0.8410 - val_accuracy: 0.6988 - lr: 1.0000e-04
# Epoch 2/100
#  1/24 [>.............................] - ETA: 2s - loss: 1.0366 - accuracy: 0.5312
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 24/24 [==============================] - ETA: 0s - loss: 0.9110 - accuracy: 0.6389
# Epoch 2: val_accuracy did not improve from 0.69880
# 24/24 [==============================] - 2s 104ms/step - loss: 0.9110 - accuracy: 0.6389 - val_loss: 0.8306 - val_accuracy: 0.6988 - lr: 1.0000e-04
# Epoch 3/100
# 24/24 [==============================] - ETA: 0s - loss: 0.9092 - accuracy: 0.6389
# Epoch 3: val_accuracy did not improve from 0.69880
# 24/24 [==============================] - 4s 168ms/step - loss: 0.9092 - accuracy: 0.6389 - val_loss: 0.8399 - val_accuracy: 0.6988 - lr: 1.0000e-04
# Epoch 4/100
# 23/24 [===========================>..] - ETA: 0s - loss: 0.9038 - accuracy: 0.6399
# Epoch 4: val_accuracy did not improve from 0.69880
# 24/24 [==============================] - 3s 112ms/step - loss: 0.9047 - accuracy: 0.6389 - val_loss: 0.8295 - val_accuracy: 0.6988 - lr: 1.0000e-04
# Epoch 5/100
# 23/24 [===========================>..] - ETA: 0s - loss: 0.8997 - accuracy: 0.6372
# Epoch 5: val_accuracy did not improve from 0.69880
# 24/24 [==============================] - 2s 96ms/step - loss: 0.8980 - accuracy: 0.6389 - val_loss: 0.8145 - val_accuracy: 0.6988 - lr: 1.0000e-04
# Epoch 6/100
# 23/24 [===========================>..] - ETA: 0s - loss: 0.8882 - accuracy: 0.6399
# Epoch 6: val_accuracy did not improve from 0.69880
# 24/24 [==============================] - 2s 95ms/step - loss: 0.8886 - accuracy: 0.6389 - val_loss: 0.8188 - val_accuracy: 0.6988 - lr: 1.0000e-04
# Epoch 7/100
# 23/24 [===========================>..] - ETA: 0s - loss: 0.8760 - accuracy: 0.6399
# Epoch 7: val_accuracy did not improve from 0.69880
# 24/24 [==============================] - 2s 95ms/step - loss: 0.8771 - accuracy: 0.6389 - val_loss: 0.8074 - val_accuracy: 0.6988 - lr: 1.0000e-04
# Epoch 8/100
# 24/24 [==============================] - ETA: 0s - loss: 0.8621 - accuracy: 0.6389
# Epoch 8: val_accuracy did not improve from 0.69880
# 24/24 [==============================] - 3s 132ms/step - loss: 0.8621 - accuracy: 0.6389 - val_loss: 0.8174 - val_accuracy: 0.6988 - lr: 1.0000e-04
# Epoch 9/100
# 23/24 [===========================>..] - ETA: 0s - loss: 0.8477 - accuracy: 0.6386
# Epoch 9: val_accuracy did not improve from 0.69880
# 24/24 [==============================] - 4s 145ms/step - loss: 0.8474 - accuracy: 0.6389 - val_loss: 0.7682 - val_accuracy: 0.6988 - lr: 1.0000e-04
# Epoch 10/100
# 23/24 [===========================>..] - ETA: 0s - loss: 0.8232 - accuracy: 0.6386
# Epoch 10: val_accuracy did not improve from 0.69880
# 24/24 [==============================] - 2s 94ms/step - loss: 0.8229 - accuracy: 0.6389 - val_loss: 0.7378 - val_accuracy: 0.6988 - lr: 1.0000e-04
# Epoch 11/100
# 23/24 [===========================>..] - ETA: 0s - loss: 0.7978 - accuracy: 0.6372
# Epoch 11: val_accuracy did not improve from 0.69880
# 24/24 [==============================] - 2s 95ms/step - loss: 0.7964 - accuracy: 0.6389 - val_loss: 0.7024 - val_accuracy: 0.6988 - lr: 1.0000e-04
# Epoch 12/100
# 23/24 [===========================>..] - ETA: 0s - loss: 0.7647 - accuracy: 0.6576
# Epoch 12: val_accuracy did not improve from 0.69880
# 24/24 [==============================] - 2s 96ms/step - loss: 0.7636 - accuracy: 0.6577 - val_loss: 0.7056 - val_accuracy: 0.6988 - lr: 1.0000e-04
# Epoch 13/100
# 23/24 [===========================>..] - ETA: 0s - loss: 0.7221 - accuracy: 0.6766
# Epoch 13: val_accuracy improved from 0.69880 to 0.74699, saving model to checkpoint/best_model.h5
# 24/24 [==============================] - 2s 102ms/step - loss: 0.7225 - accuracy: 0.6752 - val_loss: 0.6666 - val_accuracy: 0.7470 - lr: 1.0000e-04
# Epoch 14/100
# 24/24 [==============================] - ETA: 0s - loss: 0.6841 - accuracy: 0.7168
# Epoch 14: val_accuracy improved from 0.74699 to 0.75904, saving model to checkpoint/best_model.h5
# 24/24 [==============================] - 4s 167ms/step - loss: 0.6841 - accuracy: 0.7168 - val_loss: 0.6303 - val_accuracy: 0.7590 - lr: 1.0000e-04
# Epoch 15/100
# 23/24 [===========================>..] - ETA: 0s - loss: 0.6437 - accuracy: 0.7432
# Epoch 15: val_accuracy improved from 0.75904 to 0.83133, saving model to checkpoint/best_model.h5
# 24/24 [==============================] - 3s 111ms/step - loss: 0.6472 - accuracy: 0.7396 - val_loss: 0.7018 - val_accuracy: 0.8313 - lr: 1.0000e-04
# Epoch 16/100
# 23/24 [===========================>..] - ETA: 0s - loss: 0.6154 - accuracy: 0.7758
# Epoch 16: val_accuracy did not improve from 0.83133
# 24/24 [==============================] - 2s 96ms/step - loss: 0.6162 - accuracy: 0.7745 - val_loss: 0.5376 - val_accuracy: 0.7711 - lr: 1.0000e-04
# Epoch 17/100
# 23/24 [===========================>..] - ETA: 0s - loss: 0.5818 - accuracy: 0.7853
# Epoch 17: val_accuracy did not improve from 0.83133
# 24/24 [==============================] - 2s 97ms/step - loss: 0.5800 - accuracy: 0.7866 - val_loss: 0.5410 - val_accuracy: 0.7470 - lr: 1.0000e-04
# Epoch 18/100
# 23/24 [===========================>..] - ETA: 0s - loss: 0.5601 - accuracy: 0.7948
# Epoch 18: val_accuracy did not improve from 0.83133
# 24/24 [==============================] - 2s 95ms/step - loss: 0.5576 - accuracy: 0.7973 - val_loss: 0.4634 - val_accuracy: 0.8313 - lr: 1.0000e-04
# Epoch 19/100
# 24/24 [==============================] - ETA: 0s - loss: 0.5193 - accuracy: 0.8134
# Epoch 19: val_accuracy improved from 0.83133 to 0.87952, saving model to checkpoint/best_model.h5
# 24/24 [==============================] - 3s 130ms/step - loss: 0.5193 - accuracy: 0.8134 - val_loss: 0.4380 - val_accuracy: 0.8795 - lr: 1.0000e-04
# Epoch 20/100
# 23/24 [===========================>..] - ETA: 0s - loss: 0.4941 - accuracy: 0.8397
# Epoch 20: val_accuracy improved from 0.87952 to 0.89157, saving model to checkpoint/best_model.h5
# 24/24 [==============================] - 4s 156ms/step - loss: 0.4964 - accuracy: 0.8376 - val_loss: 0.4276 - val_accuracy: 0.8916 - lr: 1.0000e-04
# Epoch 21/100
# 23/24 [===========================>..] - ETA: 0s - loss: 0.4705 - accuracy: 0.8397
# Epoch 21: val_accuracy did not improve from 0.89157
# 24/24 [==============================] - 2s 98ms/step - loss: 0.4692 - accuracy: 0.8403 - val_loss: 0.4233 - val_accuracy: 0.8916 - lr: 1.0000e-05
# Epoch 22/100
# 23/24 [===========================>..] - ETA: 0s - loss: 0.4597 - accuracy: 0.8478
# Epoch 22: val_accuracy improved from 0.89157 to 0.91566, saving model to checkpoint/best_model.h5
# 24/24 [==============================] - 2s 101ms/step - loss: 0.4647 - accuracy: 0.8443 - val_loss: 0.4425 - val_accuracy: 0.9157 - lr: 1.0000e-05
# Epoch 23/100
# 23/24 [===========================>..] - ETA: 0s - loss: 0.4653 - accuracy: 0.8465
# Epoch 23: val_accuracy did not improve from 0.91566
# 24/24 [==============================] - 2s 96ms/step - loss: 0.4642 - accuracy: 0.8470 - val_loss: 0.4244 - val_accuracy: 0.9036 - lr: 1.0000e-05
# Epoch 24/100
# 23/24 [===========================>..] - ETA: 0s - loss: 0.4569 - accuracy: 0.8492
# Epoch 24: val_accuracy did not improve from 0.91566
# 24/24 [==============================] - 2s 101ms/step - loss: 0.4587 - accuracy: 0.8483 - val_loss: 0.4191 - val_accuracy: 0.9036 - lr: 1.0000e-05
# Epoch 25/100
# 24/24 [==============================] - ETA: 0s - loss: 0.4559 - accuracy: 0.8483
# Epoch 25: val_accuracy did not improve from 0.91566
# 24/24 [==============================] - 4s 173ms/step - loss: 0.4559 - accuracy: 0.8483 - val_loss: 0.4087 - val_accuracy: 0.8795 - lr: 1.0000e-05
# Epoch 26/100
# 24/24 [==============================] - ETA: 0s - loss: 0.4543 - accuracy: 0.8483
# Epoch 26: val_accuracy did not improve from 0.91566
# 24/24 [==============================] - 3s 119ms/step - loss: 0.4543 - accuracy: 0.8483 - val_loss: 0.4257 - val_accuracy: 0.9036 - lr: 1.0000e-05
# Epoch 27/100
# 23/24 [===========================>..] - ETA: 0s - loss: 0.4466 - accuracy: 0.8546
# Epoch 27: val_accuracy did not improve from 0.91566
# 24/24 [==============================] - 4s 159ms/step - loss: 0.4520 - accuracy: 0.8537 - val_loss: 0.4235 - val_accuracy: 0.9036 - lr: 1.0000e-05
# Epoch 28/100
# 23/24 [===========================>..] - ETA: 0s - loss: 0.4490 - accuracy: 0.8546
# Epoch 28: val_accuracy did not improve from 0.91566
# 24/24 [==============================] - 2s 102ms/step - loss: 0.4488 - accuracy: 0.8550 - val_loss: 0.4191 - val_accuracy: 0.9157 - lr: 1.0000e-05
# Epoch 29/100
# 24/24 [==============================] - ETA: 0s - loss: 0.4471 - accuracy: 0.8550
# Epoch 29: val_accuracy did not improve from 0.91566
# 24/24 [==============================] - 3s 136ms/step - loss: 0.4471 - accuracy: 0.8550 - val_loss: 0.4133 - val_accuracy: 0.9036 - lr: 1.0000e-05
# Epoch 30/100
# 23/24 [===========================>..] - ETA: 0s - loss: 0.4416 - accuracy: 0.8573
# Epoch 30: val_accuracy did not improve from 0.91566
# 24/24 [==============================] - 4s 145ms/step - loss: 0.4431 - accuracy: 0.8564 - val_loss: 0.4204 - val_accuracy: 0.9036 - lr: 1.0000e-05
# Epoch 31/100
# 23/24 [===========================>..] - ETA: 0s - loss: 0.4423 - accuracy: 0.8560
# Epoch 31: val_accuracy did not improve from 0.91566
# 24/24 [==============================] - 2s 98ms/step - loss: 0.4416 - accuracy: 0.8564 - val_loss: 0.4172 - val_accuracy: 0.9036 - lr: 1.0000e-05
# Epoch 32/100
# 23/24 [===========================>..] - ETA: 0s - loss: 0.4395 - accuracy: 0.8519
# Epoch 32: val_accuracy did not improve from 0.91566
# 24/24 [==============================] - 2s 99ms/step - loss: 0.4381 - accuracy: 0.8537 - val_loss: 0.3993 - val_accuracy: 0.8916 - lr: 1.0000e-05
# Epoch 33/100
# 24/24 [==============================] - ETA: 0s - loss: 0.4364 - accuracy: 0.8550
# Epoch 33: val_accuracy did not improve from 0.91566
# 24/24 [==============================] - 3s 110ms/step - loss: 0.4364 - accuracy: 0.8550 - val_loss: 0.3941 - val_accuracy: 0.9036 - lr: 1.0000e-05
# Epoch 34/100
# 24/24 [==============================] - ETA: 0s - loss: 0.4347 - accuracy: 0.8497
# Epoch 34: val_accuracy did not improve from 0.91566
# 24/24 [==============================] - 3s 107ms/step - loss: 0.4347 - accuracy: 0.8497 - val_loss: 0.4039 - val_accuracy: 0.8916 - lr: 1.0000e-05
# Epoch 35/100
# 24/24 [==============================] - ETA: 0s - loss: 0.4324 - accuracy: 0.8644
# Epoch 35: val_accuracy did not improve from 0.91566
# 24/24 [==============================] - 4s 173ms/step - loss: 0.4324 - accuracy: 0.8644 - val_loss: 0.3946 - val_accuracy: 0.8916 - lr: 1.0000e-05
# Epoch 36/100
# 23/24 [===========================>..] - ETA: 0s - loss: 0.4298 - accuracy: 0.8560
# Epoch 36: val_accuracy did not improve from 0.91566
# 24/24 [==============================] - 2s 99ms/step - loss: 0.4302 - accuracy: 0.8550 - val_loss: 0.4095 - val_accuracy: 0.9036 - lr: 1.0000e-05
# Epoch 37/100
# 23/24 [===========================>..] - ETA: 0s - loss: 0.4292 - accuracy: 0.8668
# Epoch 37: val_accuracy did not improve from 0.91566
# 24/24 [==============================] - 2s 99ms/step - loss: 0.4271 - accuracy: 0.8685 - val_loss: 0.3898 - val_accuracy: 0.9036 - lr: 1.0000e-05
# Epoch 38/100
# 23/24 [===========================>..] - ETA: 0s - loss: 0.4256 - accuracy: 0.8614
# Epoch 38: val_accuracy did not improve from 0.91566
# 24/24 [==============================] - 2s 102ms/step - loss: 0.4257 - accuracy: 0.8604 - val_loss: 0.3899 - val_accuracy: 0.9157 - lr: 1.0000e-05
# Epoch 39/100
# 23/24 [===========================>..] - ETA: 0s - loss: 0.4255 - accuracy: 0.8587
# Epoch 39: val_accuracy did not improve from 0.91566
# 24/24 [==============================] - 2s 96ms/step - loss: 0.4235 - accuracy: 0.8604 - val_loss: 0.3864 - val_accuracy: 0.9036 - lr: 1.0000e-05
# Epoch 40/100
# 24/24 [==============================] - ETA: 0s - loss: 0.4204 - accuracy: 0.8591
# Epoch 40: val_accuracy did not improve from 0.91566
# 24/24 [==============================] - 5s 199ms/step - loss: 0.4204 - accuracy: 0.8591 - val_loss: 0.3861 - val_accuracy: 0.9157 - lr: 1.0000e-05
# Epoch 41/100
# 23/24 [===========================>..] - ETA: 0s - loss: 0.4191 - accuracy: 0.8560
# Epoch 41: val_accuracy did not improve from 0.91566
# 24/24 [==============================] - 3s 111ms/step - loss: 0.4179 - accuracy: 0.8564 - val_loss: 0.3796 - val_accuracy: 0.9157 - lr: 1.0000e-05
# Epoch 42/100
# 23/24 [===========================>..] - ETA: 0s - loss: 0.4187 - accuracy: 0.8655
# Epoch 42: val_accuracy did not improve from 0.91566
# 24/24 [==============================] - 2s 98ms/step - loss: 0.4173 - accuracy: 0.8671 - val_loss: 0.3755 - val_accuracy: 0.9036 - lr: 1.0000e-05
# Epoch 43/100
# 23/24 [===========================>..] - ETA: 0s - loss: 0.4173 - accuracy: 0.8641
# Epoch 43: val_accuracy did not improve from 0.91566
# 24/24 [==============================] - 2s 95ms/step - loss: 0.4166 - accuracy: 0.8644 - val_loss: 0.3885 - val_accuracy: 0.9157 - lr: 1.0000e-05
# Epoch 44/100
# 23/24 [===========================>..] - ETA: 0s - loss: 0.
val_accuracy did not improve from 0.93976
# 24/24 [==============================] - 3s 120ms/step - loss: 0.3437 - accuracy: 0.8872 - val_loss: 0.3459 - val_accuracy: 0.9157 - lr: 1.0000e-05
# Epoch 96/100
# 23/24 [===========================>..] - ETA: 0s - loss: 0.3425 - accuracy: 0.8913
# Epoch 96: val_accuracy did not improve from 0.93976
# 24/24 [==============================] - 2s 101ms/step - loss: 0.3417 - accuracy: 0.8913 - val_loss: 0.3498 - val_accuracy: 0.9157 - lr: 1.0000e-05
# Epoch 97/100
# 23/24 [===========================>..] - ETA: 0s - loss: 0.3387 - accuracy: 0.8913
# Epoch 97: val_accuracy did not improve from 0.93976
# 24/24 [==============================] - 2s 99ms/step - loss: 0.3408 - accuracy: 0.8913 - val_loss: 0.3246 - val_accuracy: 0.9277 - lr: 1.0000e-05
# Epoch 98/100
# 23/24 [===========================>..] - ETA: 0s - loss: 0.3425 - accuracy: 0.8845
# Epoch 98: val_accuracy did not improve from 0.93976
# 24/24 [==============================] - 2s 97ms/step - loss: 0.3404 - accuracy: 0.8859 - val_loss: 0.3241 - val_accuracy: 0.9277 - lr: 1.0000e-05
# Epoch 99/100
# 24/24 [==============================] - ETA: 0s - loss: 0.3386 - accuracy: 0.8926
# Epoch 99: val_accuracy did not improve from 0.93976
# 24/24 [==============================] - 3s 134ms/step - loss: 0.3386 - accuracy: 0.8926 - val_loss: 0.3252 - val_accuracy: 0.9277 - lr: 1.0000e-05
# Epoch 100/100
# 23/24 [===========================>..] - ETA: 0s - loss: 0.3383 - accuracy: 0.8859
# Epoch 100: val_accuracy did not improve from 0.93976
# 24/24 [==============================] - 4s 153ms/step - loss: 0.3394 - accuracy: 0.8859 - val_loss: 0.3324 - val_accuracy: 0.9157 - lr: 1.0000e-05

# %%
# Plot loss per iteration
import matplotlib.pyplot as plt
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.legend()

# %%
# Plot accuracy per iteration
plt.plot(history.history['accuracy'], label='acc')
plt.plot(history.history['val_accuracy'], label='val_acc')
plt.legend()

# %%
# Plot confusion matrix
from sklearn.metrics import confusion_matrix, classification_report
import itertools

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
  """
  This function prints and plots the confusion matrix.
  Normalization can be applied by setting `normalize=True`.
  """
  if normalize:
      cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
      print("Normalized confusion matrix")
  else:
      print('Confusion matrix, without normalization')

  print(cm)

  plt.imshow(cm, interpolation='nearest', cmap=cmap)
  plt.title(title)
  plt.colorbar()
  tick_marks = np.arange(len(classes))
  plt.xticks(tick_marks, classes, rotation=45)
  plt.yticks(tick_marks, classes)

  fmt = '.2f' if normalize else 'd'
  thresh = cm.max() / 2.
  for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
      plt.text(j, i, format(cm[i, j], fmt),
               horizontalalignment="center",
               color="white" if cm[i, j] > thresh else "black")

  plt.tight_layout()
  plt.ylabel('True label')
  plt.xlabel('Predicted label')
  plt.show()

label_to_text = {0:'positive', 1:'neutral', 2:'negative'}


p_test = basemodel.predict(X_test).argmax(axis=1)
cm = confusion_matrix(y_test, p_test)
cr = classification_report(y_test, p_test, target_names=['positive', 'neutral', 'negative'], digits = 3)
print(cr)
plot_confusion_matrix(cm, list(label_to_text.values()))
# Out:
# 3/3 [==============================] - 0s 25ms/step
#               precision    recall  f1-score   support
#
#     positive      0.938     1.000     0.968        15
#      neutral      0.903     0.949     0.926        59
#     negative      0.786     0.611     0.688        18
#
#     accuracy                          0.891        92
#    macro avg      0.875     0.853     0.860        92
# weighted avg      0.886     0.891     0.886        92
#
# Confusion matrix, without normalization
# [[15  0  0]
#  [ 0 56  3]
#  [ 1  6 11]]

# %%
checkpoint_path
# Out:
# 'checkpoint/best_model.h5'

# %%
final_model = tf.keras.models.load_model(checkpoint_path)
from IPython.display import clear_output
import time

for k in range(40):
        print(f'actual label is {label_to_text[y_test[k]]}')
        predicted_class = final_model.predict(tf.expand_dims(X_test[k],0)).argmax()
        print(f'predicted label is {label_to_text[predicted_class]}')
        plt.imshow(X_test[k].reshape((48,48)))
        plt.show()
        time.sleep(3)
        clear_output(wait=True)
# Out:
# actual label is positive
# 1/1 [==============================] - 0s 20ms/step
# predicted label is positive
