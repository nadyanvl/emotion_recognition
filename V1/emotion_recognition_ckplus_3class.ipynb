# %%
# import tarfile


# fname = 'fer2013.tar.gz'
# if fname.endswith("tar.gz"):
#     tar = tarfile.open(fname, "r:gz")
#     tar.extractall()
#     tar.close()
# elif fname.endswith("tar"):
#     tar = tarfile.open(fname, "r:")
#     tar.extractall()
#     tar.close()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import pandas as pd
import numpy as np
import tensorflow as tf
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
df = pd.read_csv('/content/drive/MyDrive/face_emotion/Dataset/ckextended.csv')
df.head()
# Out:
#    emotion                                             pixels     Usage
# 0        6  36 39 35 25 19 11 8 7 3 13 15 9 21 57 75 90 10...  Training
# 1        6  88 74 19 4 5 5 3 12 8 21 15 21 15 18 24 29 32 ...  Training
# 2        6  9 2 4 7 1 1 1 0 7 29 49 76 115 141 156 169 177...  Training
# 3        6  104 106 108 104 95 50 60 61 58 83 126 133 139 ...  Training
# 4        6  68 72 67 67 6 2 1 1 1 1 1 14 24 24 38 65 79 94...  Training

# %%
df['emotion'].value_counts()
# Out:
# 6    593
# 5     83
# 3     69
# 1     59
# 0     45
# 4     28
# 2     25
# 7     18
# Name: emotion, dtype: int64

# %%
# mapping into positive, negative, neutral
# Create a dictionary to define the class mapping
class_mapping = {
    3: 0,  # happiness (Positive)
    5: 0,  # surprise (Positive)
    6: 1,  # Neutral
    0: 2,  # anger (Negative)
    1: 2,  # disgust (Negative)
    2: 2,  # fear (Negative)
    4: 2,  # sadness (Negative)
    7: 2,  # contemp (Negative)
}

# Map the 'emotion' column
df['emotion'] = df['emotion'].map(class_mapping)

# %%
df.head()
# Out:
#    emotion                                             pixels     Usage
# 0        1  36 39 35 25 19 11 8 7 3 13 15 9 21 57 75 90 10...  Training
# 1        1  88 74 19 4 5 5 3 12 8 21 15 21 15 18 24 29 32 ...  Training
# 2        1  9 2 4 7 1 1 1 0 7 29 49 76 115 141 156 169 177...  Training
# 3        1  104 106 108 104 95 50 60 61 58 83 126 133 139 ...  Training
# 4        1  68 72 67 67 6 2 1 1 1 1 1 14 24 24 38 65 79 94...  Training

# %%
df['emotion'].value_counts()
# Out:
# 1    593
# 2    175
# 0    152
# Name: emotion, dtype: int64

# %%
df.to_csv('ckextended_3class.csv', index=False)

# %%
#label_to_text = {0:'anger', 1:'disgust', 2:'fear', 3:'happiness', 4: 'sadness', 5: 'surprise', 6: 'neutral', 7 : 'contempt'}  #original
label_to_text = {0:'positive', 1:'neutral', 2:'negative'}  #edit

# %%
img_array = df.pixels.apply(lambda x: np.array(x.split(" ")).reshape(48,48,1).astype('float32'))
img_array = np.stack(img_array, axis=0)
labels = df.emotion.values

# %%
img_array.shape
# Out:
# (920, 48, 48, 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(img_array, labels, test_size= .1, random_state=42, stratify=labels)

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((828, 48, 48, 1), (828,), (92, 48, 48, 1), (92,))

# %%
X_train = X_train/255
X_test = X_test/255

# %%
# datagen = ImageDataGenerator(
#     rotation_range=15,
#     width_shift_range=0.1,
#     height_shift_range=0.1,
#     shear_range=0.2,
#     zoom_range=0.2,
#     horizontal_flip=True,
# )
# datagen.fit(X_train)

# %%
num_classes = 3

basemodel = tf.keras.models.Sequential([
                                        tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(48, 48, 1)),
                                        tf.keras.layers.MaxPool2D(2, 2),
                                        tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
                                        tf.keras.layers.MaxPool2D(2, 2),
                                        tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
                                        tf.keras.layers.Flatten(),
                                        tf.keras.layers.Dense(32, activation='relu'),
                                        #tf.keras.layers.Dropout(0.5),
                                        tf.keras.layers.Dense(num_classes, activation='softmax')
])

# %%
basemodel.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 46, 46, 32)        320
#
#  max_pooling2d (MaxPooling2  (None, 23, 23, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 21, 21, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 10, 10, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 8, 8, 128)         73856
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 32)                262176
#
#  dense_1 (Dense)             (None, 3)                 99
#
# =================================================================
# Total params: 354947 (1.35 MB)
# Trainable params: 354947 (1.35 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
initial_learning_rate = 0.0001  # You can adjust this value
optimizer = tf.keras.optimizers.RMSprop(learning_rate=initial_learning_rate)
#optimizer=tf.keras.optimizers.Adam(learning_rate=initial_learning_rate)
basemodel.compile(optimizer=optimizer,
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy'])

# %%
def lr_schedule(epoch):
    if epoch < 20:
        return initial_learning_rate
    else:
        return initial_learning_rate * 0.1

# %%
# Define early stopping
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_accuracy',
    patience=10,
    restore_best_weights=True
)

# %%
file_name = 'best_model.h5'
checkpoint_path= os.path.join('checkpoint',file_name)


call_back = [
    tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                        monitor='val_accuracy',
                                        verbose=1,
                                        save_freq='epoch',
                                        save_best_only=True,
                                        save_weights_only=False,
                                        mode='max'),
    tf.keras.callbacks.EarlyStopping(
        monitor='val_loss',
        patience=10,
        restore_best_weights=True
    ),
    tf.keras.callbacks.LearningRateScheduler(lr_schedule)
]

# %%
# history = basemodel.fit(datagen.flow(X_train, y_train, batch_size=32),
#                         epochs=40,
#                         validation_data=(X_test, y_test),
#                         callbacks=call_back)

history = basemodel.fit(X_train, y_train,
                        validation_split=.1,
                        epochs=60,
                        batch_size=16,
                        callbacks=call_back)
# Out:
# Epoch 1/60
# 46/47 [============================>.] - ETA: 0s - loss: 0.9376 - accuracy: 0.6291
# Epoch 1: val_accuracy improved from -inf to 0.69880, saving model to checkpoint/best_model.h5
# 47/47 [==============================] - 4s 57ms/step - loss: 0.9363 - accuracy: 0.6295 - val_loss: 0.8388 - val_accuracy: 0.6988 - lr: 1.0000e-04
# Epoch 2/60
#  3/47 [>.............................] - ETA: 1s - loss: 0.9194 - accuracy: 0.6250
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 47/47 [==============================] - ETA: 0s - loss: 0.9118 - accuracy: 0.6389
# Epoch 2: val_accuracy did not improve from 0.69880
# 47/47 [==============================] - 3s 65ms/step - loss: 0.9118 - accuracy: 0.6389 - val_loss: 0.8315 - val_accuracy: 0.6988 - lr: 1.0000e-04
# Epoch 3/60
# 47/47 [==============================] - ETA: 0s - loss: 0.9095 - accuracy: 0.6389
# Epoch 3: val_accuracy did not improve from 0.69880
# 47/47 [==============================] - 4s 76ms/step - loss: 0.9095 - accuracy: 0.6389 - val_loss: 0.8698 - val_accuracy: 0.6988 - lr: 1.0000e-04
# Epoch 4/60
# 46/47 [============================>.] - ETA: 0s - loss: 0.9034 - accuracy: 0.6386
# Epoch 4: val_accuracy did not improve from 0.69880
# 47/47 [==============================] - 2s 48ms/step - loss: 0.9027 - accuracy: 0.6389 - val_loss: 0.8246 - val_accuracy: 0.6988 - lr: 1.0000e-04
# Epoch 5/60
# 46/47 [============================>.] - ETA: 0s - loss: 0.8864 - accuracy: 0.6413
# Epoch 5: val_accuracy did not improve from 0.69880
# 47/47 [==============================] - 2s 51ms/step - loss: 0.8896 - accuracy: 0.6389 - val_loss: 0.8147 - val_accuracy: 0.6988 - lr: 1.0000e-04
# Epoch 6/60
# 47/47 [==============================] - ETA: 0s - loss: 0.8853 - accuracy: 0.6389
# Epoch 6: val_accuracy did not improve from 0.69880
# 47/47 [==============================] - 2s 50ms/step - loss: 0.8853 - accuracy: 0.6389 - val_loss: 0.8043 - val_accuracy: 0.6988 - lr: 1.0000e-04
# Epoch 7/60
# 46/47 [============================>.] - ETA: 0s - loss: 0.8725 - accuracy: 0.6386
# Epoch 7: val_accuracy did not improve from 0.69880
# 47/47 [==============================] - 2s 49ms/step - loss: 0.8718 - accuracy: 0.6389 - val_loss: 0.7820 - val_accuracy: 0.6988 - lr: 1.0000e-04
# Epoch 8/60
# 47/47 [==============================] - ETA: 0s - loss: 0.8512 - accuracy: 0.6389
# Epoch 8: val_accuracy did not improve from 0.69880
# 47/47 [==============================] - 4s 86ms/step - loss: 0.8512 - accuracy: 0.6389 - val_loss: 0.7550 - val_accuracy: 0.6988 - lr: 1.0000e-04
# Epoch 9/60
# 46/47 [============================>.] - ETA: 0s - loss: 0.8284 - accuracy: 0.6386
# Epoch 9: val_accuracy did not improve from 0.69880
# 47/47 [==============================] - 2s 51ms/step - loss: 0.8275 - accuracy: 0.6389 - val_loss: 0.7244 - val_accuracy: 0.6988 - lr: 1.0000e-04
# Epoch 10/60
# 47/47 [==============================] - ETA: 0s - loss: 0.7954 - accuracy: 0.6403
# Epoch 10: val_accuracy improved from 0.69880 to 0.71084, saving model to checkpoint/best_model.h5
# 47/47 [==============================] - 2s 49ms/step - loss: 0.7954 - accuracy: 0.6403 - val_loss: 0.6858 - val_accuracy: 0.7108 - lr: 1.0000e-04
# Epoch 11/60
# 46/47 [============================>.] - ETA: 0s - loss: 0.7523 - accuracy: 0.6644
# Epoch 11: val_accuracy improved from 0.71084 to 0.77108, saving model to checkpoint/best_model.h5
# 47/47 [==============================] - 2s 49ms/step - loss: 0.7523 - accuracy: 0.6644 - val_loss: 0.6438 - val_accuracy: 0.7711 - lr: 1.0000e-04
# Epoch 12/60
# 47/47 [==============================] - ETA: 0s - loss: 0.7144 - accuracy: 0.6940
# Epoch 12: val_accuracy improved from 0.77108 to 0.84337, saving model to checkpoint/best_model.h5
# 47/47 [==============================] - 2s 49ms/step - loss: 0.7144 - accuracy: 0.6940 - val_loss: 0.6604 - val_accuracy: 0.8434 - lr: 1.0000e-04
# Epoch 13/60
# 47/47 [==============================] - ETA: 0s - loss: 0.6673 - accuracy: 0.7383
# Epoch 13: val_accuracy did not improve from 0.84337
# 47/47 [==============================] - 3s 70ms/step - loss: 0.6673 - accuracy: 0.7383 - val_loss: 0.5462 - val_accuracy: 0.8072 - lr: 1.0000e-04
# Epoch 14/60
# 46/47 [============================>.] - ETA: 0s - loss: 0.6267 - accuracy: 0.7568
# Epoch 14: val_accuracy did not improve from 0.84337
# 47/47 [==============================] - 3s 70ms/step - loss: 0.6249 - accuracy: 0.7584 - val_loss: 0.5120 - val_accuracy: 0.8193 - lr: 1.0000e-04
# Epoch 15/60
# 46/47 [============================>.] - ETA: 0s - loss: 0.5831 - accuracy: 0.7785
# Epoch 15: val_accuracy improved from 0.84337 to 0.87952, saving model to checkpoint/best_model.h5
# 47/47 [==============================] - 2s 52ms/step - loss: 0.5816 - accuracy: 0.7785 - val_loss: 0.4964 - val_accuracy: 0.8795 - lr: 1.0000e-04
# Epoch 16/60
# 47/47 [==============================] - ETA: 0s - loss: 0.5475 - accuracy: 0.8040
# Epoch 16: val_accuracy did not improve from 0.87952
# 47/47 [==============================] - 2s 49ms/step - loss: 0.5475 - accuracy: 0.8040 - val_loss: 0.4473 - val_accuracy: 0.8675 - lr: 1.0000e-04
# Epoch 17/60
# 46/47 [============================>.] - ETA: 0s - loss: 0.5123 - accuracy: 0.8043
# Epoch 17: val_accuracy did not improve from 0.87952
# 47/47 [==============================] - 2s 49ms/step - loss: 0.5168 - accuracy: 0.8027 - val_loss: 0.5038 - val_accuracy: 0.8434 - lr: 1.0000e-04
# Epoch 18/60
# 47/47 [==============================] - ETA: 0s - loss: 0.4837 - accuracy: 0.8322
# Epoch 18: val_accuracy did not improve from 0.87952
# 47/47 [==============================] - 3s 54ms/step - loss: 0.4837 - accuracy: 0.8322 - val_loss: 0.3998 - val_accuracy: 0.8554 - lr: 1.0000e-04
# Epoch 19/60
# 46/47 [============================>.] - ETA: 0s - loss: 0.4573 - accuracy: 0.8356
# Epoch 19: val_accuracy did not improve from 0.87952
# 47/47 [==============================] - 4s 88ms/step - loss: 0.4589 - accuracy: 0.8336 - val_loss: 0.4625 - val_accuracy: 0.8313 - lr: 1.0000e-04
# Epoch 20/60
# 47/47 [==============================] - ETA: 0s - loss: 0.4339 - accuracy: 0.8416
# Epoch 20: val_accuracy did not improve from 0.87952
# 47/47 [==============================] - 2s 49ms/step - loss: 0.4339 - accuracy: 0.8416 - val_loss: 0.4841 - val_accuracy: 0.8434 - lr: 1.0000e-04
# Epoch 21/60
# 46/47 [============================>.] - ETA: 0s - loss: 0.4064 - accuracy: 0.8628
# Epoch 21: val_accuracy improved from 0.87952 to 0.90361, saving model to checkpoint/best_model.h5
# 47/47 [==============================] - 2s 51ms/step - loss: 0.4046 - accuracy: 0.8644 - val_loss: 0.3684 - val_accuracy: 0.9036 - lr: 1.0000e-05
# Epoch 22/60
# 46/47 [============================>.] - ETA: 0s - loss: 0.3906 - accuracy: 0.8764
# Epoch 22: val_accuracy improved from 0.90361 to 0.91566, saving model to checkpoint/best_model.h5
# 47/47 [==============================] - 2s 50ms/step - loss: 0.3928 - accuracy: 0.8738 - val_loss: 0.3756 - val_accuracy: 0.9157 - lr: 1.0000e-05
# Epoch 23/60
# 47/47 [==============================] - ETA: 0s - loss: 0.3906 - accuracy: 0.8765
# Epoch 23: val_accuracy did not improve from 0.91566
# 47/47 [==============================] - 2s 52ms/step - loss: 0.3906 - accuracy: 0.8765 - val_loss: 0.3602 - val_accuracy: 0.9036 - lr: 1.0000e-05
# Epoch 24/60
# 47/47 [==============================] - ETA: 0s - loss: 0.3877 - accuracy: 0.8779
# Epoch 24: val_accuracy did not improve from 0.91566
# 47/47 [==============================] - 4s 80ms/step - loss: 0.3877 - accuracy: 0.8779 - val_loss: 0.3623 - val_accuracy: 0.9157 - lr: 1.0000e-05
# Epoch 25/60
# 46/47 [============================>.] - ETA: 0s - loss: 0.3849 - accuracy: 0.8777
# Epoch 25: val_accuracy did not improve from 0.91566
# 47/47 [==============================] - 3s 61ms/step - loss: 0.3829 - accuracy: 0.8792 - val_loss: 0.3483 - val_accuracy: 0.9157 - lr: 1.0000e-05
# Epoch 26/60
# 46/47 [============================>.] - ETA: 0s - loss: 0.3856 - accuracy: 0.8736
# Epoch 26: val_accuracy did not improve from 0.91566
# 47/47 [==============================] - 2s 51ms/step - loss: 0.3835 - accuracy: 0.8752 - val_loss: 0.3540 - val_accuracy: 0.9036 - lr: 1.0000e-05
# Epoch 27/60
# 46/47 [============================>.] - ETA: 0s - loss: 0.3756 - accuracy: 0.8832
# Epoch 27: val_accuracy did not improve from 0.91566
# 47/47 [==============================] - 2s 49ms/step - loss: 0.3790 - accuracy: 0.8819 - val_loss: 0.3676 - val_accuracy: 0.9157 - lr: 1.0000e-05
# Epoch 28/60
# 47/47 [==============================] - ETA: 0s - loss: 0.3759 - accuracy: 0.8832
# Epoch 28: val_accuracy did not improve from 0.91566
# 47/47 [==============================] - 2s 51ms/step - loss: 0.3759 - accuracy: 0.8832 - val_loss: 0.3488 - val_accuracy: 0.9036 - lr: 1.0000e-05
# Epoch 29/60
# 47/47 [==============================] - ETA: 0s - loss: 0.3746 - accuracy: 0.8779
# Epoch 29: val_accuracy did not improve from 0.91566
# 47/47 [==============================] - 3s 65ms/step - loss: 0.3746 - accuracy: 0.8779 - val_loss: 0.3508 - val_accuracy: 0.9157 - lr: 1.0000e-05
# Epoch 30/60
# 46/47 [============================>.] - ETA: 0s - loss: 0.3726 - accuracy: 0.8736
# Epoch 30: val_accuracy did not improve from 0.91566
# 47/47 [==============================] - 4s 76ms/step - loss: 0.3709 - accuracy: 0.8752 - val_loss: 0.3420 - val_accuracy: 0.9036 - lr: 1.0000e-05
# Epoch 31/60
# 47/47 [==============================] - ETA: 0s - loss: 0.3697 - accuracy: 0.8819
# Epoch 31: val_accuracy did not improve from 0.91566
# 47/47 [==============================] - 2s 49ms/step - loss: 0.3697 - accuracy: 0.8819 - val_loss: 0.3531 - val_accuracy: 0.9157 - lr: 1.0000e-05
# Epoch 32/60
# 47/47 [==============================] - ETA: 0s - loss: 0.3672 - accuracy: 0.8752
# Epoch 32: val_accuracy did not improve from 0.91566
# 47/47 [==============================] - 3s 54ms/step - loss: 0.3672 - accuracy: 0.8752 - val_loss: 0.3438 - val_accuracy: 0.9157 - lr: 1.0000e-05
# Epoch 33/60
# 46/47 [============================>.] - ETA: 0s - loss: 0.3670 - accuracy: 0.8832
# Epoch 33: val_accuracy did not improve from 0.91566
# 47/47 [==============================] - 4s 84ms/step - loss: 0.3647 - accuracy: 0.8846 - val_loss: 0.3374 - val_accuracy: 0.9036 - lr: 1.0000e-05
# Epoch 34/60
# 47/47 [==============================] - ETA: 0s - loss: 0.3628 - accuracy: 0.8819
# Epoch 34: val_accuracy did not improve from 0.91566
# 47/47 [==============================] - 4s 80ms/step - loss: 0.3628 - accuracy: 0.8819 - val_loss: 0.3434 - val_accuracy: 0.9157 - lr: 1.0000e-05
# Epoch 35/60
# 46/47 [============================>.] - ETA: 0s - loss: 0.3556 - accuracy: 0.8845
# Epoch 35: val_accuracy did not improve from 0.91566
# 47/47 [==============================] - 3s 61ms/step - loss: 0.3593 - accuracy: 0.8832 - val_loss: 0.3560 - val_accuracy: 0.9036 - lr: 1.0000e-05
# Epoch 36/60
# 46/47 [============================>.] - ETA: 0s - loss: 0.3584 - accuracy: 0.8804
# Epoch 36: val_accuracy did not improve from 0.91566
# 47/47 [==============================] - 2s 51ms/step - loss: 0.3584 - accuracy: 0.8805 - val_loss: 0.3387 - val_accuracy: 0.9157 - lr: 1.0000e-05
# Epoch 37/60
# 46/47 [============================>.] - ETA: 0s - loss: 0.3588 - accuracy: 0.8804
# Epoch 37: val_accuracy did not improve from 0.91566
# 47/47 [==============================] - 2s 51ms/step - loss: 0.3570 - accuracy: 0.8819 - val_loss: 0.3404 - val_accuracy: 0.9157 - lr: 1.0000e-05
# Epoch 38/60
# 47/47 [==============================] - ETA: 0s - loss: 0.3522 - accuracy: 0.8765
# Epoch 38: val_accuracy did not improve from 0.91566
# 47/47 [==============================] - 2s 52ms/step - loss: 0.3522 - accuracy: 0.8765 - val_loss: 0.3348 - val_accuracy: 0.9157 - lr: 1.0000e-05
# Epoch 39/60
# 47/47 [==============================] - ETA: 0s - loss: 0.3520 - accuracy: 0.8886
# Epoch 39: val_accuracy did not improve from 0.91566
# 47/47 [==============================] - 3s 67ms/step - loss: 0.3520 - accuracy: 0.8886 - val_loss: 0.3318 - val_accuracy: 0.9157 - lr: 1.0000e-05
# Epoch 40/60
# 46/47 [============================>.] - ETA: 0s - loss: 0.3482 - accuracy: 0.8899
# Epoch 40: val_accuracy did not improve from 0.91566
# 47/47 [==============================] - 4s 75ms/step - loss: 0.3501 - accuracy: 0.8899 - val_loss: 0.3308 - val_accuracy: 0.9157 - lr: 1.0000e-05
# Epoch 41/60
# 46/47 [============================>.] - ETA: 0s - loss: 0.3469 - accuracy: 0.8859
# Epoch 41: val_accuracy did not improve from 0.91566
# 47/47 [==============================] - 2s 49ms/step - loss: 0.3490 - accuracy: 0.8846 - val_loss: 0.3346 - val_accuracy: 0.9157 - lr: 1.0000e-05
# Epoch 42/60
# 47/47 [==============================] - ETA: 0s - loss: 0.3444 - accuracy: 0.8886
# Epoch 42: val_accuracy did not improve from 0.91566
# 47/47 [==============================] - 2s 50ms/step - loss: 0.3444 - accuracy: 0.8886 - val_loss: 0.3226 - val_accuracy: 0.9036 - lr: 1.0000e-05
# Epoch 43/60
# 46/47 [============================>.] - ETA: 0s - loss: 0.3435 - accuracy: 0.8872
# Epoch 43: val_accuracy did not improve from 0.91566
# 47/47 [==============================] - 2s 50ms/step - loss: 0.3441 - accuracy: 0.8872 - val_loss: 0.3309 - val_accuracy: 0.9157 - lr: 1.0000e-05
# Epoch 44/60
# 46/47 [============================>.] - ETA: 0s - loss: 0.3399 - accuracy: 0.8872
# Epoch 44: val_accuracy did not improve from 0.91566
# 47/47 [==============================] - 2s 51ms/step - loss: 0.3410 - accuracy: 0.8859 - val_loss: 0.3422 - val_accuracy: 0.9157 - lr: 1.0000e-05
# Epoch 45/60
# 47/47 [==============================] - ETA: 0s - loss: 0.3402 - accuracy: 0.8846
# Epoch 45: val_accuracy improved from 0.91566 to 0.92771, saving model to checkpoint/best_model.h5
# 47/47 [==============================] - 4s 87ms/step - loss: 0.3402 - accuracy: 0.8846 - val_loss: 0.3368 - val_accuracy: 0.9277 - lr: 1.0000e-05
# Epoch 46/60
# 46/47 [============================>.] - ETA: 0s - loss: 0.3389 - accuracy: 0.8927
# Epoch 46: val_accuracy did not improve from 0.92771
# 47/47 [==============================] - 2s 51ms/step - loss: 0.3387 - accuracy: 0.8926 - val_loss: 0.3183 - val_accuracy: 0.9157 - lr: 1.0000e-05
# Epoch 47/60
# 47/47 [==============================] - ETA: 0s - loss: 0.3366 - accuracy: 0.8886
# Epoch 47: val_accuracy did not improve from 0.92771
# 47/47 [==============================] - 2s 49ms/step - loss: 0.3366 - accuracy: 0.8886 - val_loss: 0.3174 - val_accuracy: 0.9157 - lr: 1.0000e-05
# Epoch 48/60
# 46/47 [============================>.] - ETA: 0s - loss: 0.3337 - accuracy: 0.8927
# Epoch 48: val_accuracy did not improve from 0.92771
# 47/47 [==============================] - 2s 49ms/step - loss: 0.3351 - accuracy: 0.8926 - val_loss: 0.3250 - val_accuracy: 0.9157 - lr: 1.0000e-05
# Epoch 49/60
# 46/47 [============================>.] - ETA: 0s - loss: 0.3303 - accuracy: 0.8886
# Epoch 49: val_accuracy did not improve from 0.92771
# 47/47 [==============================] - 2s 49ms/step - loss: 0.3313 - accuracy: 0.8872 - val_loss: 0.3233 - val_accuracy: 0.9277 - lr: 1.0000e-05
# Epoch 50/60
# 46/47 [============================>.] - ETA: 0s - loss: 0.3338 - accuracy: 0.8913
# Epoch 50: val_accuracy did not improve from 0.92771
# 47/47 [==============================] - 4s 84ms/step - loss: 0.3317 - accuracy: 0.8926 - val_loss: 0.3108 - val_accuracy: 0.9036 - lr: 1.0000e-05
# Epoch 51/60
# 47/47 [==============================] - ETA: 0s - loss: 0.3288 - accuracy: 0.8993
# Epoch 51: val_accuracy did not improve from 0.92771
# 47/47 [==============================] - 4s 96ms/step - loss: 0.3288 - accuracy: 0.8993 - val_loss: 0.3069 - val_accuracy: 0.9157 - lr: 1.0000e-05
# Epoch 52/60
# 47/47 [==============================] - ETA: 0s - loss: 0.3306 - accuracy: 0.8899
# Epoch 52: val_accuracy did not improve from 0.92771
# 47/47 [==============================] - 3s 64ms/step - loss: 0.3306 - accuracy: 0.8899 - val_loss: 0.3103 - val_accuracy: 0.9157 - lr: 1.0000e-05
# Epoch 53/60
# 46/47 [============================>.] - ETA: 0s - loss: 0.3243 - accuracy: 0.8940
# Epoch 53: val_accuracy did not improve from 0.92771
# 47/47 [==============================] - 2s 49ms/step - loss: 0.3244 - accuracy: 0.8940 - val_loss: 0.3073 - val_accuracy: 0.9036 - lr: 1.0000e-05
# Epoch 54/60
# 47/47 [==============================] - ETA: 0s - loss: 0.3247 - accuracy: 0.8940
# Epoch 54: val_accuracy did not improve from 0.92771
# 47/47 [==============================] - 2s 49ms/step - loss: 0.3247 - accuracy: 0.8940 - val_loss: 0.3245 - val_accuracy: 0.9277 - lr: 1.0000e-05
# Epoch 55/60
# 46/47 [============================>.] - ETA: 0s - loss: 0.3200 - accuracy: 0.8940
# Epoch 55: val_accuracy did not improve from 0.92771
# 47/47 [==============================] - 2s 49ms/step - loss: 0.3228 - accuracy: 0.8940 - val_loss: 0.3040 - val_accuracy: 0.9157 - lr: 1.0000e-05
# Epoch 56/60
# 47/47 [==============================] - ETA: 0s - loss: 0.3230 - accuracy: 0.8913
# Epoch 56: val_accuracy did not improve from 0.92771
# 47/47 [==============================] - 3s 63ms/step - loss: 0.3230 - accuracy: 0.8913 - val_loss: 0.3174 - val_accuracy: 0.9277 - lr: 1.0000e-05
# Epoch 57/60
# 47/47 [==============================] - ETA: 0s - loss: 0.3204 - accuracy: 0.8953
# Epoch 57: val_accuracy did not improve from 0.92771
# 47/47 [==============================] - 4s 78ms/step - loss: 0.3204 - accuracy: 0.8953 - val_loss: 0.3045 - val_accuracy: 0.9157 - lr: 1.0000e-05
# Epoch 58/60
# 46/47 [============================>.] - ETA: 0s - loss: 0.3190 - accuracy: 0.8967
# Epoch 58: val_accuracy did not improve from 0.92771
# 47/47 [==============================] - 2s 50ms/step - loss: 0.3195 - accuracy: 0.8980 - val_loss: 0.3107 - val_accuracy: 0.9277 - lr: 1.0000e-05
# Epoch 59/60
# 46/47 [============================>.] - ETA: 0s - loss: 0.3154 - accuracy: 0.8954
# Epoch 59: val_accuracy did not improve from 0.92771
# 47/47 [==============================] - 2s 49ms/step - loss: 0.3176 - accuracy: 0.8953 - val_loss: 0.3075 - val_accuracy: 0.9157 - lr: 1.0000e-05
# Epoch 60/60
# 47/47 [==============================] - ETA: 0s - loss: 0.3134 - accuracy: 0.8953
# Epoch 60: val_accuracy did not improve from 0.92771
# 47/47 [==============================] - 2s 50ms/step - loss: 0.3134 - accuracy: 0.8953 - val_loss: 0.3031 - val_accuracy: 0.9277 - lr: 1.0000e-05

# %%
# Plot loss per iteration
import matplotlib.pyplot as plt
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.legend()

# %%
# Plot accuracy per iteration
plt.plot(history.history['accuracy'], label='acc')
plt.plot(history.history['val_accuracy'], label='val_acc')
plt.legend()

# %%
# Plot confusion matrix
from sklearn.metrics import confusion_matrix, classification_report
import itertools

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
  """
  This function prints and plots the confusion matrix.
  Normalization can be applied by setting `normalize=True`.
  """
  if normalize:
      cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
      print("Normalized confusion matrix")
  else:
      print('Confusion matrix, without normalization')

  print(cm)

  plt.imshow(cm, interpolation='nearest', cmap=cmap)
  plt.title(title)
  plt.colorbar()
  tick_marks = np.arange(len(classes))
  plt.xticks(tick_marks, classes, rotation=45)
  plt.yticks(tick_marks, classes)

  fmt = '.2f' if normalize else 'd'
  thresh = cm.max() / 2.
  for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
      plt.text(j, i, format(cm[i, j], fmt),
               horizontalalignment="center",
               color="white" if cm[i, j] > thresh else "black")

  plt.tight_layout()
  plt.ylabel('True label')
  plt.xlabel('Predicted label')
  plt.show()

label_to_text = {0:'positive', 1:'neutral', 2:'negative'}


p_test = basemodel.predict(X_test).argmax(axis=1)
cm = confusion_matrix(y_test, p_test)
cr = classification_report(y_test, p_test, target_names=['positive', 'neutral', 'negative'])
print(cr)
plot_confusion_matrix(cm, list(label_to_text.values()))
# Out:
# 3/3 [==============================] - 0s 64ms/step
#               precision    recall  f1-score   support
#
#     positive       0.94      1.00      0.97        15
#      neutral       0.88      0.95      0.91        59
#     negative       0.75      0.50      0.60        18
#
#     accuracy                           0.87        92
#    macro avg       0.85      0.82      0.83        92
# weighted avg       0.86      0.87      0.86        92
#
# Confusion matrix, without normalization
# [[15  0  0]
#  [ 0 56  3]
#  [ 1  8  9]]

# %%
checkpoint_path
# Out:
# 'checkpoint/best_model.h5'

# %%
final_model = tf.keras.models.load_model(checkpoint_path)
from IPython.display import clear_output
import time

for k in range(40):
        print(f'actual label is {label_to_text[y_test[k]]}')
        predicted_class = final_model.predict(tf.expand_dims(X_test[k],0)).argmax()
        print(f'predicted label is {label_to_text[predicted_class]}')
        plt.imshow(X_test[k].reshape((48,48)))
        plt.show()
        time.sleep(3)
        clear_output(wait=True)
# Out:
# actual label is positive
# 1/1 [==============================] - 0s 21ms/step
# predicted label is positive
